# %%
# pandas
import pandas as pd

# random
import random

# NLTK packages
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.tag import pos_tag as pos_tagger
from nltk import UnigramTagger

# Textblob
from textblob import TextBlob

# %%
#import the json-file and put it in a dataframe
df = pd.read_json('reviewSelected100.json', lines=True, encoding = "ISO-8859-1")

#dataframe
df
# Out:
#                     review_id                 user_id             business_id  \
# 0      8aoJJdKEO3ypoZNszpPu7Q  bGgAL09pxLnV_FFgR4ZADg  ZBE-H_aUlicix_9vUGQPIQ
# 1      J5NOCLdhuhor7USRhtYZ8w  pFCb-1j6oI3TDjr26h2cJQ  e-YnECeZNt8ngm0tu4X9mQ
# 2      PXiLWAYRt3xnHaJ8MB4rzw  mEzc6LeTNiQgIVsq3poMbg  j7HO1YeMQGYo3KibMXZ5vg
# 3      VrLarvxZYJm74yAqtpe9PQ  o-zUN2WEZgjQS7jnNsec0g  7e3PZzUpG5FYOTGt3O3ePA
# 4      C1CUpidlVFprUCkApqzCmA  Wlx0iBXJvk4x0EeOt2Bz1Q  vuHzLZ7nAeT-EiecOkS5Og
# ...                       ...                     ...                     ...
# 15295  qknwFVEh_0KSuexigYBI_A  YMGmyPOU65SMs4H60ltYiw  shIPnFoXrL3dFo5HLH1_HA
# 15296  Y-ZRoyAXCukBK1uK1ZcZCA  JLhOWQiWtGbr14K_KmoWxA  zPEYgVqJ2QNKi45FJi2jvg
# 15297  A8HdjBfhj3pgQuSbwNtDEw  6CoiKFDFXIACJZvv_I_8mQ  zPEYgVqJ2QNKi45FJi2jvg
# 15298  2n1QdrYBRAAe6GKaxEV0jA  _fH4s3ls08eSl_PfX38KIA  etzDsNjkCyQBoJcU2a3U-g
# 15299  4B9k5hmmLWV_lhIYvVcPWA  msRUiBE7Sa5A9145ZdFBow  9Xm2GfG8Rnbb1_CmXyrm3g
#
# ...

# %%
#select all the text
text = df['text'].astype('str') 

#join all the text into one string
all_text = ''.join(map(str, text))


#full string
#all_text

# %%
#separating the string into sentences
sentences = sent_tokenize(all_text)

#sentences

# %%
#select 5 random sentences
random_5_sentences = random.choices(sentences, k=5)

pd.options.display.max_colwidth = 300
pd.DataFrame(random_5_sentences, columns=['sentence'])
# Out:
#                                                                                                                                           sentence
# 0                                                                             So at that point, we were out of there, totally put-off and annoyed.
# 1                        1.called to order, lady who took my order spoke clearly and followed me, not someone half listening trying to multi task.
# 2  And here I foolishly thought that doling out $4.99 for a tub of Dazs or Ben 'n Jerry's was an indulgence... Move aside and make space for Ed's!
# 3                                                                                            The freshly made food items are unique and delicious.
# 4                                                                                                              I have been going there since 2010.

# %%
def pos_tag(chosen_sentence):
    # using NLTK
    random_sentence_nltk = nltk.pos_tag(word_tokenize(chosen_sentence))

    # using textblob
    random_sentence_blob = TextBlob(chosen_sentence)
    random_sentence_blob.tags

    # respective table
    table_sentence_nltk = pd.DataFrame(random_sentence_nltk, columns=['word', 'POS_Tag'])
    table_sentence_blob = pd.DataFrame(random_sentence_blob.tags, columns=['word', 'POS_Tag'])
                                        
    return table_sentence_nltk, table_sentence_blob

# %%
# Function for display two tables side by side
from IPython.display import display_html
from itertools import chain,cycle
def display_side_by_side(*args,titles=cycle([''])):
    html_str=''
    for df,title in zip(args, chain(titles,cycle(['</br>'])) ):
        html_str+='<th style="text-align:center"><td style="vertical-align:top">'
        html_str+=f'<h2>{title}</h2>'
        html_str+=df.to_html().replace('table','table style="display:inline"')
        html_str+='</td></th>'
    display_html(html_str,raw=True)

# %%
#nltk.download('averaged_perceptron_tagger')
for i in range(len(random_5_sentences)):
    nltk_s, textb_s = pos_tag(random_5_sentences[i])
    print("---------- Sentence "+ str(i+1) + " ----------")
    print("Sentence: " + random_5_sentences[i])
    display_side_by_side(nltk_s, textb_s, titles=['NLTK','TextBlob'])
# Out:
# ---------- Sentence 1 ----------
# Sentence: So at that point, we were out of there, totally put-off and annoyed.
# <th style="text-align:center"><td style="vertical-align:top"><h2>NLTK</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>word</th>
#       <th>POS_Tag</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>So</td>
#       <td>RB</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>at</td>
#       <td>IN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>that</td>
#       <td>DT</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>point</td>
#       <td>NN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>,</td>
#       <td>,</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>we</td>
#       <td>PRP</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>were</td>
#       <td>VBD</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Observation
# Both NLTK and TextBlob produces the same POS_TAG, just that NLTK takes into consideration punctuations as well.
